# %% [markdown]
# <a href="https://colab.research.google.com/github/Rimich666/sberautopodpiska/blob/master/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Task3_step3_AutoML_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 0. Монтирование диска с датасетом
from google.colab import drive
drive.mount('/content/drive', force_remount=True)  # Принудительное перемонтирование
# Out:
# Mounted at /content/drive

# %%
# 1. Установка библиотек
# !pip install -U lightautoml pandas scikit-learn imbalanced-learn
# Out:
# Requirement already satisfied: lightautoml in /usr/local/lib/python3.11/dist-packages (0.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.3.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.11/dist-packages (0.13.0)
# Requirement already satisfied: SQLAlchemy>=2.0 in /usr/local/lib/python3.11/dist-packages (from lightautoml) (2.0.41)
# Requirement already satisfied: autowoe>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from lightautoml) (1.3.4)
# Requirement already satisfied: catboost>=0.26.1 in /usr/local/lib/python3.11/dist-packages (from lightautoml) (1.2.8)
# Requirement already satisfied: cmaes in /usr/local/lib/python3.11/dist-packages (from lightautoml) (0.12.0)
# Requirement already satisfied: holidays in /usr/local/lib/python3.11/dist-packages (from lightautoml) (0.76)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from lightautoml) (3.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from lightautoml) (1.5.1)
# Requirement already satisfied: json2html in /usr/local/lib/python3.11/dist-packages (from lightautoml) (1.3.0)
# Requirement already satisfied: lightgbm>=2.3 in /usr/local/lib/python3.11/dist-packages (from lightautoml) (4.6.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from lightautoml) (3.5)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.11/dist-packages (from lightautoml) (1.26.4)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (from lightautoml) (4.4.0)
# Requirement already satisfied: poetry-core<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from lightautoml) (1.9.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from lightautoml) (6.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightautoml) (1.16.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from lightautoml) (0.13.2)
# Requirement already satisfied: statsmodels<=0.14.0 in /usr/local/lib/python3.11/dist-packages (from lightautoml) (0.14.0)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from lightautoml) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from lightautoml) (4.67.1)
# Requirement already satisfied: xgboost<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from lightautoml) (2.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: StrEnum<0.5.0,>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from autowoe>=1.3.3->lightautoml) (0.4.15)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from autowoe>=1.3.3->lightautoml) (3.10.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from autowoe>=1.3.3->lightautoml) (8.4.1)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.11/dist-packages (from autowoe>=1.3.3->lightautoml) (8.2.3)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from autowoe>=1.3.3->lightautoml) (3.0.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost>=0.26.1->lightautoml) (0.21)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost>=0.26.1->lightautoml) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost>=0.26.1->lightautoml) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy>=2.0->lightautoml) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy>=2.0->lightautoml) (4.14.1)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from statsmodels<=0.14.0->lightautoml) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels<=0.14.0->lightautoml) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (3.18.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (2025.7.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->lightautoml) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.9.0->lightautoml) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->lightautoml) (3.0.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna->lightautoml) (1.16.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna->lightautoml) (6.9.0)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->lightautoml) (1.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->autowoe>=1.3.3->lightautoml) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->autowoe>=1.3.3->lightautoml) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->autowoe>=1.3.3->lightautoml) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->autowoe>=1.3.3->lightautoml) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->autowoe>=1.3.3->lightautoml) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->autowoe>=1.3.3->lightautoml) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost>=0.26.1->lightautoml) (8.5.0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.11/dist-packages (from pytest->autowoe>=1.3.3->lightautoml) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->autowoe>=1.3.3->lightautoml) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from pytest->autowoe>=1.3.3->lightautoml) (2.19.2)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx->autowoe>=1.3.3->lightautoml) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx->autowoe>=1.3.3->lightautoml) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx->autowoe>=1.3.3->lightautoml) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx->autowoe>=1.3.3->lightautoml) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx->autowoe>=1.3.3->lightautoml) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx->autowoe>=1.3.3->lightautoml) (2.0.0)
# Requirement already satisfied: docutils<0.22,>=0.20 in /usr/local/lib/python3.11/dist-packages (from sphinx->autowoe>=1.3.3->lightautoml) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx->autowoe>=1.3.3->lightautoml) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx->autowoe>=1.3.3->lightautoml) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx->autowoe>=1.3.3->lightautoml) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx->autowoe>=1.3.3->lightautoml) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from sphinx->autowoe>=1.3.3->lightautoml) (2.32.3)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx->autowoe>=1.3.3->lightautoml) (3.1.0)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.11/dist-packages (from sphinx-rtd-theme->autowoe>=1.3.3->lightautoml) (4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx->autowoe>=1.3.3->lightautoml) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx->autowoe>=1.3.3->lightautoml) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx->autowoe>=1.3.3->lightautoml) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx->autowoe>=1.3.3->lightautoml) (2025.7.14)

# %%
# 2. Импорт модулей
import warnings
warnings.simplefilter('ignore', FutureWarning)

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    precision_score, recall_score, f1_score,
    roc_auc_score, precision_recall_curve, auc
)

from imblearn.over_sampling import RandomOverSampler

from lightautoml.automl.presets.tabular_presets import TabularAutoML
from lightautoml.tasks import Task
# Out:
# WARNING:lightautoml.utils.installation:'nlp' extra dependency package 'gensim' isn't installed. Look at README.md in repo 'LightAutoML' for installation instructions.
# WARNING:lightautoml.utils.installation:'nlp' extra dependency package 'gensim' isn't installed. Look at README.md in repo 'LightAutoML' for installation instructions.
# /usr/local/lib/python3.11/dist-packages/lightautoml/transformers/text.py:22: UserWarning: 'gensim' - package isn't installed
#   warnings.warn("'gensim' - package isn't installed")

# %%
# 3. Чтение датасета
df = pd.read_csv(
    '/content/drive/MyDrive/Проектный практикум (хакатон)/cleaned_sessions_new.csv',
    low_memory=False
)

# %%
# 4) Метка «1» для целевых событий
target_events = [
    'sub_car_claim_click',
    'sub_car_claim_submit_click',
    'sub_open_dialog_click',
    'sub_custom_question_submit_click',
    'sub_call_number_click',
    'sub_callback_submit_click',
    'sub_submit_success',
    'sub_car_request_submit_click'
]
df['target_column'] = df['event_action'].isin(target_events).astype(int)

# %%
# 5) Поведенческие признаки (до удаления event_action и session_id)
df['events_per_session']        = df.groupby('session_id')['event_action'].transform('count')
df['unique_events_per_session'] = df.groupby('session_id')['event_action'].transform('nunique')

# %%
# 6) Временные признаки
df['visit_date'] = pd.to_datetime(df['visit_date'], format='%Y-%m-%d', errors='coerce')
df['visit_time'] = pd.to_timedelta(df['visit_time'], errors='coerce')
df['visit_dt']   = df['visit_date'] + df['visit_time']

df['visit_hour']      = df['visit_dt'].dt.hour
df['visit_dayofweek'] = df['visit_dt'].dt.dayofweek

sess_min = df.groupby('session_id')['visit_dt'].transform('min')
sess_max = df.groupby('session_id')['visit_dt'].transform('max')
df['session_duration_s'] = (sess_max - sess_min).dt.total_seconds()

# %%
# 7) Удаляем колонки-утечки
df.drop([
    'visit_date', 'visit_time', 'visit_dt',
    'event_action', 'session_id'
], axis=1, inplace=True)

# %%
# 8) Формируем сбалансированный подвыбор, где положительных событий в 2 раза меньше отрицательных
n_event = len(df[df['target_column'] == 1])
df_short = pd.concat([
    df[df['target_column'] == 1],
    df[df['target_column'] == 0].sample(n=2*n_event, random_state=12)
]).reset_index(drop=True)

# %%
# 9) Разбиение на train/test из этого сбалансированного подвыбора
train_df, test_df = train_test_split(
    df_short,
    test_size=0.2,
    stratify=df_short['target_column'],
    random_state=42
)

# %%
# 10) Настройка AutoML
automl = TabularAutoML(
    task=Task('binary'),
    timeout=600,       # 10 минут
    cpu_limit=4,       # до 4 ядер
    reader_params={'n_jobs':4}
)
roles = {'target':'target_column'}

# %%
# 11) Обучение и получение OOF‑предсказаний на train
oof_pred    = automl.fit_predict(train_data=train_df, valid_data=None, roles=roles, verbose=1)
train_proba = oof_pred.data.ravel()
y_train_oof = train_df['target_column'].values
# Out:
# [16:28:11] Stdout logging level is INFO.
# INFO:lightautoml.automl.presets.base:Stdout logging level is INFO.
# [16:28:11] Copying TaskTimer may affect the parent PipelineTimer, so copy will create new unlimited TaskTimer
# WARNING:lightautoml.utils.timer:Copying TaskTimer may affect the parent PipelineTimer, so copy will create new unlimited TaskTimer
# [16:28:11] Task: binary
# INFO:lightautoml.automl.presets.base:Task: binary
# [16:28:11] Start automl preset with listed constraints:
# INFO:lightautoml.automl.presets.base:Start automl preset with listed constraints:
# [16:28:11] - time: 600.00 seconds
# INFO:lightautoml.automl.presets.base:- time: 600.00 seconds
# [16:28:11] - CPU: 4 cores
# INFO:lightautoml.automl.presets.base:- CPU: 4 cores
# [16:28:11] - memory: 16 GB
# INFO:lightautoml.automl.presets.base:- memory: 16 GB
# [16:28:11] Train data shape: (12736, 22)
# INFO:lightautoml.reader.base:Train data shape: (12736, 22)
#
# INFO3:lightautoml.reader.base:Feats was rejected during automatic roles guess: []
# [16:28:24] Layer 1 train process start. Time left 587.39 secs
# INFO:lightautoml.automl.base:Layer 1 train process start. Time left 587.39 secs
# [16:28:25] Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'tol': 1e-06, 'max_iter': 100, 'cs': [1e-05, 5e-05, 0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000], 'early_stopping': 2, 'categorical_idx': [0, 1, 2, 3, 4, 12], 'embed_sizes': array([12,  5,  3,  8, 23, 11], dtype=int32), 'data_size': 39}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = 0.6398345593715142
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = 0.6525084734247472
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = 0.65864594360571
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = 0.6675973741915671
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = 0.670526416495257
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = 0.675101268604618
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = 0.6762070254032893
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = 0.6778937378115444
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = 0.6778937378115444
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = 0.6794126802227596
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = 0.6794126802227596
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5 score = 0.6794126802227596
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = 0.6272806225296579
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = 0.6358003110428536
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = 0.6388538584158457
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = 0.6415279668035976
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = 0.6425691695766238
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = 0.644932512579755
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = 0.6460645864808735
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = 0.6492131670183587
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = 0.6492131670183587
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = 0.6532732335277005
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = 0.6532732335277005
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5 score = 0.6532732335277005
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = 0.6143155323036456
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = 0.6301461845918639
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = 0.6357475919151057
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = 0.6415262326217639
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = 0.6428230537970951
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = 0.6458876999338237
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = 0.6465848410310198
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = 0.6501406074630862
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = 0.6501406074630862
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = 0.6591978923447663
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = 0.6591978923447663
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5 score = 0.6591978923447663
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = 0.6261176801918976
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = 0.6335673785136258
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = 0.636007025517445
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = 0.6408675903612786
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = 0.6426385368499767
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = 0.6498263737147979
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = 0.6524394389019994
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = 0.6555131027842636
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = 0.6555131027842636
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = 0.6589530258698308
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = 0.6589530258698308
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5 score = 0.6589530258698308
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = 0.6415314351672653
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = 0.6499588652069017
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = 0.6530557671257392
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = 0.6564554571927619
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = 0.6570894740712069
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = 0.6577033744403795
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = 0.6574175812741658
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = 0.6583207431732198
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = 0.6583207431732198
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = 0.6622476245177239
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = 0.6622476245177239
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5 score = 0.6622476245177239
# [16:28:33] Fitting Lvl_0_Pipe_0_Mod_0_LinearL2 finished. score = 0.6621754288716148
# INFO:lightautoml.ml_algo.base:Fitting Lvl_0_Pipe_0_Mod_0_LinearL2 finished. score = 0.6621754288716148
# [16:28:33] Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# [16:28:33] Time left 578.49 secs
# INFO:lightautoml.automl.base:Time left 578.49 secs
#
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.602806
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.599106
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [8]	valid's auc: 0.607217
# [16:28:34] Selector_LightGBM fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Selector_LightGBM fitting and predicting completed
# [16:28:34] Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'task': 'train', 'learning_rate': 0.02, 'num_leaves': 64, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 0.2, 'reg_lambda': 0.0, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 2, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 3000, 'early_stopping_rounds': 200, 'random_state': 42, 'verbose_eval': 100}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.611495
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.609982
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [6]	valid's auc: 0.617503
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.630502
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.623385
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [39]	valid's auc: 0.63752
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.640962
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.634643
# INFO3:lightautoml.ml_algo.boost_lgbm:[300]	valid's auc: 0.630368
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [113]	valid's auc: 0.641832
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.602909
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.599647
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [5]	valid's auc: 0.612362
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.604852
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.599931
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [25]	valid's auc: 0.608451
# [16:28:36] Fitting Lvl_0_Pipe_1_Mod_0_LightGBM finished. score = 0.6206742981101447
# INFO:lightautoml.ml_algo.base:Fitting Lvl_0_Pipe_1_Mod_0_LightGBM finished. score = 0.6206742981101447
# [16:28:36] Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# [16:28:36] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ... Time budget is 117.28 secs
# INFO:lightautoml.ml_algo.tuning.optuna:Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ... Time budget is 117.28 secs
# Optimization Progress:   0%|          | 0/101 [00:00<?, ?it/s]INFO:optuna.storages._in_memory:A new study created in memory with name: no-name-8f6ccebd-9b69-4f9f-a201-a4d37a9404f0
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.607429
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.596894
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [22]	valid's auc: 0.615422
# INFO:optuna.study.study:Trial 0 finished with value: 0.6154226382733279 and parameters: {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07}. Best is trial 0 with value: 0.6154226382733279.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 1 with hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07} scored 0.6154226382733279 in 0:00:00.892684
# Optimization Progress:   1%|          | 1/101 [00:00<01:30,  1.10it/s, best_trial=0, best_value=0.615]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.61643
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.608748
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [6]	valid's auc: 0.624222
# INFO:optuna.study.study:Trial 1 finished with value: 0.6242215506800578 and parameters: {'feature_fraction': 0.5290418060840998, 'num_leaves': 223, 'bagging_fraction': 0.8005575058716043, 'min_sum_hessian_in_leaf': 0.679657809075816, 'reg_alpha': 1.5320059381854043e-08, 'reg_lambda': 5.360294728728285}. Best is trial 1 with value: 0.6242215506800578.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 2 with hyperparameters {'feature_fraction': 0.5290418060840998, 'num_leaves': 223, 'bagging_fraction': 0.8005575058716043, 'min_sum_hessian_in_leaf': 0.679657809075816, 'reg_alpha': 1.5320059381854043e-08, 'reg_lambda': 5.360294728728285} scored 0.6242215506800578 in 0:00:00.691036
# Optimization Progress:   2%|▏         | 2/101 [00:01<01:17,  1.27it/s, best_trial=1, best_value=0.624]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.612176
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.609425
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [23]	valid's auc: 0.614666
# INFO:optuna.study.study:Trial 2 finished with value: 0.6146655934932972 and parameters: {'feature_fraction': 0.9162213204002109, 'num_leaves': 66, 'bagging_fraction': 0.5909124836035503, 'min_sum_hessian_in_leaf': 0.00541524411940254, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323}. Best is trial 1 with value: 0.6242215506800578.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 3 with hyperparameters {'feature_fraction': 0.9162213204002109, 'num_leaves': 66, 'bagging_fraction': 0.5909124836035503, 'min_sum_hessian_in_leaf': 0.00541524411940254, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323} scored 0.6146655934932972 in 0:00:00.578461
# Optimization Progress:   3%|▎         | 3/101 [00:02<01:08,  1.43it/s, best_trial=1, best_value=0.624]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.614588
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.610748
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [5]	valid's auc: 0.621048
# INFO:optuna.study.study:Trial 3 finished with value: 0.6210477860253139 and parameters: {'feature_fraction': 0.7159725093210578, 'num_leaves': 85, 'bagging_fraction': 0.8059264473611898, 'min_sum_hessian_in_leaf': 0.003613894271216527, 'reg_alpha': 4.258943089524393e-06, 'reg_lambda': 1.9826980964985924e-05}. Best is trial 1 with value: 0.6242215506800578.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 4 with hyperparameters {'feature_fraction': 0.7159725093210578, 'num_leaves': 85, 'bagging_fraction': 0.8059264473611898, 'min_sum_hessian_in_leaf': 0.003613894271216527, 'reg_alpha': 4.258943089524393e-06, 'reg_lambda': 1.9826980964985924e-05} scored 0.6210477860253139 in 0:00:03.385312
# Optimization Progress:   4%|▍         | 4/101 [00:05<02:51,  1.76s/it, best_trial=1, best_value=0.624]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.602657
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.594937
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [35]	valid's auc: 0.610031
# INFO:optuna.study.study:Trial 4 finished with value: 0.6100314672734117 and parameters: {'feature_fraction': 0.728034992108518, 'num_leaves': 204, 'bagging_fraction': 0.5998368910791798, 'min_sum_hessian_in_leaf': 0.11400863701127326, 'reg_alpha': 0.0021465011216654484, 'reg_lambda': 2.6185068507773707e-08}. Best is trial 1 with value: 0.6242215506800578.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 5 with hyperparameters {'feature_fraction': 0.728034992108518, 'num_leaves': 204, 'bagging_fraction': 0.5998368910791798, 'min_sum_hessian_in_leaf': 0.11400863701127326, 'reg_alpha': 0.0021465011216654484, 'reg_lambda': 2.6185068507773707e-08} scored 0.6100314672734117 in 0:00:00.983955
# Optimization Progress:   5%|▍         | 5/101 [00:06<02:22,  1.49s/it, best_trial=1, best_value=0.624]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.619962
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.619336
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [21]	valid's auc: 0.62407
# INFO:optuna.study.study:Trial 5 finished with value: 0.6240704190298318 and parameters: {'feature_fraction': 0.8037724259507192, 'num_leaves': 56, 'bagging_fraction': 0.5325257964926398, 'min_sum_hessian_in_leaf': 6.245139574743075, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936}. Best is trial 1 with value: 0.6242215506800578.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 6 with hyperparameters {'feature_fraction': 0.8037724259507192, 'num_leaves': 56, 'bagging_fraction': 0.5325257964926398, 'min_sum_hessian_in_leaf': 6.245139574743075, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936} scored 0.6240704190298318 in 0:00:00.436367
# Optimization Progress:   6%|▌         | 6/101 [00:07<01:47,  1.14s/it, best_trial=1, best_value=0.624]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.624265
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.619079
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [18]	valid's auc: 0.628483
# INFO:optuna.study.study:Trial 6 finished with value: 0.6284830472577578 and parameters: {'feature_fraction': 0.6523068845866853, 'num_leaves': 39, 'bagging_fraction': 0.8421165132560784, 'min_sum_hessian_in_leaf': 0.057624872164786026, 'reg_alpha': 1.254134495897175e-07, 'reg_lambda': 0.00028614897264046574}. Best is trial 6 with value: 0.6284830472577578.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 7 with hyperparameters {'feature_fraction': 0.6523068845866853, 'num_leaves': 39, 'bagging_fraction': 0.8421165132560784, 'min_sum_hessian_in_leaf': 0.057624872164786026, 'reg_alpha': 1.254134495897175e-07, 'reg_lambda': 0.00028614897264046574} scored 0.6284830472577578 in 0:00:00.356993
# Optimization Progress:   7%|▋         | 7/101 [00:07<01:23,  1.13it/s, best_trial=6, best_value=0.628]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.613721
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.603704
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [4]	valid's auc: 0.616518
# INFO:optuna.study.study:Trial 7 finished with value: 0.6165179961052404 and parameters: {'feature_fraction': 0.5171942605576092, 'num_leaves': 234, 'bagging_fraction': 0.6293899908000085, 'min_sum_hessian_in_leaf': 0.4467752817973907, 'reg_alpha': 6.388511557344611e-06, 'reg_lambda': 0.0004793052550782129}. Best is trial 6 with value: 0.6284830472577578.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 8 with hyperparameters {'feature_fraction': 0.5171942605576092, 'num_leaves': 234, 'bagging_fraction': 0.6293899908000085, 'min_sum_hessian_in_leaf': 0.4467752817973907, 'reg_alpha': 6.388511557344611e-06, 'reg_lambda': 0.0004793052550782129} scored 0.6165179961052404 in 0:00:00.755298
# Optimization Progress:   8%|▊         | 8/101 [00:08<01:18,  1.18it/s, best_trial=6, best_value=0.628]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.619514
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.616921
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [15]	valid's auc: 0.627628
# INFO:optuna.study.study:Trial 8 finished with value: 0.6276279055579704 and parameters: {'feature_fraction': 0.7733551396716398, 'num_leaves': 60, 'bagging_fraction': 0.9847923138822793, 'min_sum_hessian_in_leaf': 1.2604664585649468, 'reg_alpha': 2.854239907497756, 'reg_lambda': 1.1309571585271483}. Best is trial 6 with value: 0.6284830472577578.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 9 with hyperparameters {'feature_fraction': 0.7733551396716398, 'num_leaves': 60, 'bagging_fraction': 0.9847923138822793, 'min_sum_hessian_in_leaf': 1.2604664585649468, 'reg_alpha': 2.854239907497756, 'reg_lambda': 1.1309571585271483} scored 0.6276279055579704 in 0:00:00.502417
# Optimization Progress:   9%|▉         | 9/101 [00:08<01:08,  1.34it/s, best_trial=6, best_value=0.628]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.604414
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.596068
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [31]	valid's auc: 0.61455
# INFO:optuna.study.study:Trial 9 finished with value: 0.614550164962276 and parameters: {'feature_fraction': 0.7989499894055425, 'num_leaves': 237, 'bagging_fraction': 0.5442462510259598, 'min_sum_hessian_in_leaf': 0.006080390190296602, 'reg_alpha': 2.5529693461039728e-08, 'reg_lambda': 8.471746987003668e-06}. Best is trial 6 with value: 0.6284830472577578.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 10 with hyperparameters {'feature_fraction': 0.7989499894055425, 'num_leaves': 237, 'bagging_fraction': 0.5442462510259598, 'min_sum_hessian_in_leaf': 0.006080390190296602, 'reg_alpha': 2.5529693461039728e-08, 'reg_lambda': 8.471746987003668e-06} scored 0.614550164962276 in 0:00:00.955301
# Optimization Progress:  10%|▉         | 10/101 [00:09<01:14,  1.23it/s, best_trial=6, best_value=0.628]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.62484
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.624605
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [14]	valid's auc: 0.626449
# INFO:optuna.study.study:Trial 10 finished with value: 0.6264493559919887 and parameters: {'feature_fraction': 0.6229610028762618, 'num_leaves': 17, 'bagging_fraction': 0.9515481201295128, 'min_sum_hessian_in_leaf': 0.024400771927662206, 'reg_alpha': 0.002507789482047843, 'reg_lambda': 0.016301353379407527}. Best is trial 6 with value: 0.6284830472577578.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 11 with hyperparameters {'feature_fraction': 0.6229610028762618, 'num_leaves': 17, 'bagging_fraction': 0.9515481201295128, 'min_sum_hessian_in_leaf': 0.024400771927662206, 'reg_alpha': 0.002507789482047843, 'reg_lambda': 0.016301353379407527} scored 0.6264493559919887 in 0:00:00.292614
# Optimization Progress:  11%|█         | 11/101 [00:09<00:59,  1.52it/s, best_trial=6, best_value=0.628]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.624409
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.622216
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [5]	valid's auc: 0.627375
# INFO:optuna.study.study:Trial 11 finished with value: 0.6273745174012842 and parameters: {'feature_fraction': 0.8673512178923002, 'num_leaves': 118, 'bagging_fraction': 0.9743245943075546, 'min_sum_hessian_in_leaf': 3.105840981358399, 'reg_alpha': 8.540823200302832, 'reg_lambda': 0.01881061891210943}. Best is trial 6 with value: 0.6284830472577578.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 12 with hyperparameters {'feature_fraction': 0.8673512178923002, 'num_leaves': 118, 'bagging_fraction': 0.9743245943075546, 'min_sum_hessian_in_leaf': 3.105840981358399, 'reg_alpha': 8.540823200302832, 'reg_lambda': 0.01881061891210943} scored 0.6273745174012842 in 0:00:00.377465
# Optimization Progress:  12%|█▏        | 12/101 [00:10<00:51,  1.73it/s, best_trial=6, best_value=0.628]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.623407
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.621012
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [4]	valid's auc: 0.631451
# INFO:optuna.study.study:Trial 12 finished with value: 0.6314512590029053 and parameters: {'feature_fraction': 0.631590611326652, 'num_leaves': 26, 'bagging_fraction': 0.9009799030302936, 'min_sum_hessian_in_leaf': 0.032772539629616924, 'reg_alpha': 0.07178352731373416, 'reg_lambda': 9.61381188507591}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 13 with hyperparameters {'feature_fraction': 0.631590611326652, 'num_leaves': 26, 'bagging_fraction': 0.9009799030302936, 'min_sum_hessian_in_leaf': 0.032772539629616924, 'reg_alpha': 0.07178352731373416, 'reg_lambda': 9.61381188507591} scored 0.6314512590029053 in 0:00:00.362093
# Optimization Progress:  13%|█▎        | 13/101 [00:10<00:45,  1.94it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.625195
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.623909
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [2]	valid's auc: 0.629596
# INFO:optuna.study.study:Trial 13 finished with value: 0.62959608333316 and parameters: {'feature_fraction': 0.6079180203564427, 'num_leaves': 16, 'bagging_fraction': 0.6985437619179986, 'min_sum_hessian_in_leaf': 0.024142096469713267, 'reg_alpha': 0.07099362035346235, 'reg_lambda': 1.5155324681197734e-05}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 14 with hyperparameters {'feature_fraction': 0.6079180203564427, 'num_leaves': 16, 'bagging_fraction': 0.6985437619179986, 'min_sum_hessian_in_leaf': 0.024142096469713267, 'reg_alpha': 0.07099362035346235, 'reg_lambda': 1.5155324681197734e-05} scored 0.62959608333316 in 0:00:00.288866
# Optimization Progress:  14%|█▍        | 14/101 [00:11<00:39,  2.22it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.614916
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.606588
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [26]	valid's auc: 0.621934
# INFO:optuna.study.study:Trial 14 finished with value: 0.6219341246253772 and parameters: {'feature_fraction': 0.6007962363563226, 'num_leaves': 167, 'bagging_fraction': 0.7057671919735079, 'min_sum_hessian_in_leaf': 0.023506997063237126, 'reg_alpha': 0.021794939340193196, 'reg_lambda': 2.659335589816979e-06}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 15 with hyperparameters {'feature_fraction': 0.6007962363563226, 'num_leaves': 167, 'bagging_fraction': 0.7057671919735079, 'min_sum_hessian_in_leaf': 0.023506997063237126, 'reg_alpha': 0.021794939340193196, 'reg_lambda': 2.659335589816979e-06} scored 0.6219341246253772 in 0:00:00.785568
# Optimization Progress:  15%|█▍        | 15/101 [00:11<00:47,  1.80it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.617541
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.619697
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [63]	valid's auc: 0.62015
# INFO:optuna.study.study:Trial 15 finished with value: 0.6201496619295906 and parameters: {'feature_fraction': 0.9996812193207756, 'num_leaves': 16, 'bagging_fraction': 0.6919414715215033, 'min_sum_hessian_in_leaf': 0.021004805863831095, 'reg_alpha': 0.15203858593612088, 'reg_lambda': 0.014775475739688166}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 16 with hyperparameters {'feature_fraction': 0.9996812193207756, 'num_leaves': 16, 'bagging_fraction': 0.6919414715215033, 'min_sum_hessian_in_leaf': 0.021004805863831095, 'reg_alpha': 0.15203858593612088, 'reg_lambda': 0.014775475739688166} scored 0.6201496619295906 in 0:00:00.390501
# Optimization Progress:  16%|█▌        | 16/101 [00:12<00:43,  1.95it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.616804
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.609959
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [12]	valid's auc: 0.621304
# INFO:optuna.study.study:Trial 16 finished with value: 0.6213039472398023 and parameters: {'feature_fraction': 0.5787600873010279, 'num_leaves': 111, 'bagging_fraction': 0.9040330172235821, 'min_sum_hessian_in_leaf': 0.0010726564906192127, 'reg_alpha': 0.10617472907820692, 'reg_lambda': 9.436857527570946e-05}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 17 with hyperparameters {'feature_fraction': 0.5787600873010279, 'num_leaves': 111, 'bagging_fraction': 0.9040330172235821, 'min_sum_hessian_in_leaf': 0.0010726564906192127, 'reg_alpha': 0.10617472907820692, 'reg_lambda': 9.436857527570946e-05} scored 0.6213039472398023 in 0:00:00.609079
# Optimization Progress:  17%|█▋        | 17/101 [00:12<00:45,  1.83it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.6132
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.604922
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [6]	valid's auc: 0.621163
# INFO:optuna.study.study:Trial 17 finished with value: 0.6211625212918844 and parameters: {'feature_fraction': 0.5615029388010604, 'num_leaves': 160, 'bagging_fraction': 0.7472223931930823, 'min_sum_hessian_in_leaf': 0.0704999672181294, 'reg_alpha': 6.033712858982701e-05, 'reg_lambda': 5.275377541258301e-07}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 18 with hyperparameters {'feature_fraction': 0.5615029388010604, 'num_leaves': 160, 'bagging_fraction': 0.7472223931930823, 'min_sum_hessian_in_leaf': 0.0704999672181294, 'reg_alpha': 6.033712858982701e-05, 'reg_lambda': 5.275377541258301e-07} scored 0.6211625212918844 in 0:00:00.690926
# Optimization Progress:  18%|█▊        | 18/101 [00:13<00:49,  1.68it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.61788
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.611318
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [26]	valid's auc: 0.621809
# INFO:optuna.study.study:Trial 18 finished with value: 0.6218093370242733 and parameters: {'feature_fraction': 0.6834099353180804, 'num_leaves': 100, 'bagging_fraction': 0.6723232288001568, 'min_sum_hessian_in_leaf': 0.009579972946947277, 'reg_alpha': 0.3604891361973204, 'reg_lambda': 0.0029459105636035505}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 19 with hyperparameters {'feature_fraction': 0.6834099353180804, 'num_leaves': 100, 'bagging_fraction': 0.6723232288001568, 'min_sum_hessian_in_leaf': 0.009579972946947277, 'reg_alpha': 0.3604891361973204, 'reg_lambda': 0.0029459105636035505} scored 0.6218093370242733 in 0:00:00.641646
# Optimization Progress:  19%|█▉        | 19/101 [00:14<00:50,  1.63it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.623023
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.617817
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [29]	valid's auc: 0.625147
# INFO:optuna.study.study:Trial 19 finished with value: 0.6251477519860293 and parameters: {'feature_fraction': 0.6365791618523396, 'num_leaves': 38, 'bagging_fraction': 0.7586225915398586, 'min_sum_hessian_in_leaf': 0.0017842006430236555, 'reg_alpha': 0.00881846940418744, 'reg_lambda': 0.545567984517963}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 20 with hyperparameters {'feature_fraction': 0.6365791618523396, 'num_leaves': 38, 'bagging_fraction': 0.7586225915398586, 'min_sum_hessian_in_leaf': 0.0017842006430236555, 'reg_alpha': 0.00881846940418744, 'reg_lambda': 0.545567984517963} scored 0.6251477519860293 in 0:00:00.424439
# Optimization Progress:  20%|█▉        | 20/101 [00:14<00:45,  1.78it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.614709
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.605637
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [24]	valid's auc: 0.618425
# INFO:optuna.study.study:Trial 20 finished with value: 0.6184248199765537 and parameters: {'feature_fraction': 0.5005387409854178, 'num_leaves': 150, 'bagging_fraction': 0.9052348365849548, 'min_sum_hessian_in_leaf': 0.09759223981386288, 'reg_alpha': 0.0003618544594881128, 'reg_lambda': 1.6340250254137068e-08}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 21 with hyperparameters {'feature_fraction': 0.5005387409854178, 'num_leaves': 150, 'bagging_fraction': 0.9052348365849548, 'min_sum_hessian_in_leaf': 0.09759223981386288, 'reg_alpha': 0.0003618544594881128, 'reg_lambda': 1.6340250254137068e-08} scored 0.6184248199765537 in 0:00:00.871651
# Optimization Progress:  21%|██        | 21/101 [00:15<00:52,  1.51it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.62185
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.620318
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [28]	valid's auc: 0.626195
# INFO:optuna.study.study:Trial 21 finished with value: 0.6261949279386267 and parameters: {'feature_fraction': 0.6505718221669831, 'num_leaves': 37, 'bagging_fraction': 0.8514169434142767, 'min_sum_hessian_in_leaf': 0.05381929678690269, 'reg_alpha': 0.7329033038835093, 'reg_lambda': 8.630083636387952e-05}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 22 with hyperparameters {'feature_fraction': 0.6505718221669831, 'num_leaves': 37, 'bagging_fraction': 0.8514169434142767, 'min_sum_hessian_in_leaf': 0.05381929678690269, 'reg_alpha': 0.7329033038835093, 'reg_lambda': 8.630083636387952e-05} scored 0.6261949279386267 in 0:00:03.225580
# Optimization Progress:  22%|██▏       | 22/101 [00:18<01:53,  1.44s/it, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.623388
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.61997
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [33]	valid's auc: 0.626259
# INFO:optuna.study.study:Trial 22 finished with value: 0.6262587082680797 and parameters: {'feature_fraction': 0.6627556236256741, 'num_leaves': 36, 'bagging_fraction': 0.8240200917292068, 'min_sum_hessian_in_leaf': 0.013723140383733424, 'reg_alpha': 0.037377196131838805, 'reg_lambda': 0.0021069733329307327}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 23 with hyperparameters {'feature_fraction': 0.6627556236256741, 'num_leaves': 36, 'bagging_fraction': 0.8240200917292068, 'min_sum_hessian_in_leaf': 0.013723140383733424, 'reg_alpha': 0.037377196131838805, 'reg_lambda': 0.0021069733329307327} scored 0.6262587082680797 in 0:00:00.459345
# Optimization Progress:  23%|██▎       | 23/101 [00:19<01:29,  1.15s/it, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.619313
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.614117
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [12]	valid's auc: 0.62454
# INFO:optuna.study.study:Trial 23 finished with value: 0.6245397590628728 and parameters: {'feature_fraction': 0.5624940689357021, 'num_leaves': 81, 'bagging_fraction': 0.9178539575784554, 'min_sum_hessian_in_leaf': 0.04133206909441453, 'reg_alpha': 0.00012425980173560598, 'reg_lambda': 4.0615905400353225e-05}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 24 with hyperparameters {'feature_fraction': 0.5624940689357021, 'num_leaves': 81, 'bagging_fraction': 0.9178539575784554, 'min_sum_hessian_in_leaf': 0.04133206909441453, 'reg_alpha': 0.00012425980173560598, 'reg_lambda': 4.0615905400353225e-05} scored 0.6245397590628728 in 0:00:00.506478
# Optimization Progress:  24%|██▍       | 24/101 [00:19<01:13,  1.04it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.622031
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.618167
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [24]	valid's auc: 0.62418
# INFO:optuna.study.study:Trial 24 finished with value: 0.6241799548130231 and parameters: {'feature_fraction': 0.6091330191487014, 'num_leaves': 40, 'bagging_fraction': 0.7544259445792262, 'min_sum_hessian_in_leaf': 0.17064080638695586, 'reg_alpha': 7.774047830351397e-07, 'reg_lambda': 3.6244464006940615e-06}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 25 with hyperparameters {'feature_fraction': 0.6091330191487014, 'num_leaves': 40, 'bagging_fraction': 0.7544259445792262, 'min_sum_hessian_in_leaf': 0.17064080638695586, 'reg_alpha': 7.774047830351397e-07, 'reg_lambda': 3.6244464006940615e-06} scored 0.6241799548130231 in 0:00:00.436234
# Optimization Progress:  25%|██▍       | 25/101 [00:20<01:01,  1.24it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.621398
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.618003
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [14]	valid's auc: 0.623838
# INFO:optuna.study.study:Trial 25 finished with value: 0.623837828806663 and parameters: {'feature_fraction': 0.71079821973025, 'num_leaves': 16, 'bagging_fraction': 0.859160133924645, 'min_sum_hessian_in_leaf': 0.0371901485386204, 'reg_alpha': 0.0004530781170200388, 'reg_lambda': 5.202043802286749e-07}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 26 with hyperparameters {'feature_fraction': 0.71079821973025, 'num_leaves': 16, 'bagging_fraction': 0.859160133924645, 'min_sum_hessian_in_leaf': 0.0371901485386204, 'reg_alpha': 0.0004530781170200388, 'reg_lambda': 5.202043802286749e-07} scored 0.623837828806663 in 0:00:00.309434
# Optimization Progress:  26%|██▌       | 26/101 [00:20<00:49,  1.51it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.614547
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.610922
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's auc: 0.616265
# INFO:optuna.study.study:Trial 26 finished with value: 0.6162653012130048 and parameters: {'feature_fraction': 0.7463152694739921, 'num_leaves': 74, 'bagging_fraction': 0.7728140719136602, 'min_sum_hessian_in_leaf': 0.33068684899203726, 'reg_alpha': 0.007607527421464864, 'reg_lambda': 0.10378183742735612}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 27 with hyperparameters {'feature_fraction': 0.7463152694739921, 'num_leaves': 74, 'bagging_fraction': 0.7728140719136602, 'min_sum_hessian_in_leaf': 0.33068684899203726, 'reg_alpha': 0.007607527421464864, 'reg_lambda': 0.10378183742735612} scored 0.6162653012130048 in 0:00:00.506102
# Optimization Progress:  27%|██▋       | 27/101 [00:21<00:45,  1.61it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.621998
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.615729
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [27]	valid's auc: 0.624398
# INFO:optuna.study.study:Trial 27 finished with value: 0.6243979864827298 and parameters: {'feature_fraction': 0.5867543214912573, 'num_leaves': 52, 'bagging_fraction': 0.719586323643176, 'min_sum_hessian_in_leaf': 0.012720837859130394, 'reg_alpha': 3.356296021419834e-05, 'reg_lambda': 0.0011627263181236637}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 28 with hyperparameters {'feature_fraction': 0.5867543214912573, 'num_leaves': 52, 'bagging_fraction': 0.719586323643176, 'min_sum_hessian_in_leaf': 0.012720837859130394, 'reg_alpha': 3.356296021419834e-05, 'reg_lambda': 0.0011627263181236637} scored 0.6243979864827298 in 0:00:00.496870
# Optimization Progress:  28%|██▊       | 28/101 [00:21<00:42,  1.70it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.617252
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.609595
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [8]	valid's auc: 0.621548
# INFO:optuna.study.study:Trial 28 finished with value: 0.6215483229586308 and parameters: {'feature_fraction': 0.6662593198117106, 'num_leaves': 98, 'bagging_fraction': 0.6448418252158186, 'min_sum_hessian_in_leaf': 0.14728742851448648, 'reg_alpha': 1.0701739490924475e-07, 'reg_lambda': 0.0001596663361902688}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 29 with hyperparameters {'feature_fraction': 0.6662593198117106, 'num_leaves': 98, 'bagging_fraction': 0.6448418252158186, 'min_sum_hessian_in_leaf': 0.14728742851448648, 'reg_alpha': 1.0701739490924475e-07, 'reg_lambda': 0.0001596663361902688} scored 0.6215483229586308 in 0:00:00.566888
# Optimization Progress:  29%|██▊       | 29/101 [00:22<00:42,  1.70it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.612891
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.607216
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [2]	valid's auc: 0.619413
# INFO:optuna.study.study:Trial 29 finished with value: 0.6194127218186267 and parameters: {'feature_fraction': 0.54647131309892, 'num_leaves': 188, 'bagging_fraction': 0.8873549505650266, 'min_sum_hessian_in_leaf': 0.002804433271869901, 'reg_alpha': 1.013929538003361, 'reg_lambda': 1.8667945735464275e-06}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 30 with hyperparameters {'feature_fraction': 0.54647131309892, 'num_leaves': 188, 'bagging_fraction': 0.8873549505650266, 'min_sum_hessian_in_leaf': 0.002804433271869901, 'reg_alpha': 1.013929538003361, 'reg_lambda': 1.8667945735464275e-06} scored 0.6194127218186267 in 0:00:00.649340
# Optimization Progress:  30%|██▉       | 30/101 [00:22<00:43,  1.63it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.619504
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.616684
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [6]	valid's auc: 0.621371
# INFO:optuna.study.study:Trial 30 finished with value: 0.6213705006270578 and parameters: {'feature_fraction': 0.7002615440438447, 'num_leaves': 28, 'bagging_fraction': 0.8361961588337358, 'min_sum_hessian_in_leaf': 0.21821333893652015, 'reg_alpha': 2.579708256605169e-07, 'reg_lambda': 9.243625021455677e-08}. Best is trial 12 with value: 0.6314512590029053.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 31 with hyperparameters {'feature_fraction': 0.7002615440438447, 'num_leaves': 28, 'bagging_fraction': 0.8361961588337358, 'min_sum_hessian_in_leaf': 0.21821333893652015, 'reg_alpha': 2.579708256605169e-07, 'reg_lambda': 9.243625021455677e-08} scored 0.6213705006270578 in 0:00:00.344884
# Optimization Progress:  31%|███       | 31/101 [00:23<00:37,  1.85it/s, best_trial=12, best_value=0.631]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.61944
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.61693
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [15]	valid's auc: 0.627719
# ...
# INFO3:lightautoml.ml_algo.boost_cb:300:	test: 0.6287302	best: 0.6294949 (265)	total: 847ms	remaining: 13.2s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.6294948667
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 265
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 266 iterations.
# INFO:optuna.study.study:Trial 93 finished with value: 0.6294948667233757 and parameters: {'max_depth': 5, 'nan_mode': 'Min', 'l2_leaf_reg': 2.4887989308736865e-06, 'min_data_in_leaf': 10}. Best is trial 5 with value: 0.6308210816173305.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 94 with hyperparameters {'max_depth': 5, 'nan_mode': 'Min', 'l2_leaf_reg': 2.4887989308736865e-06, 'min_data_in_leaf': 10} scored 0.6294948667233757 in 0:00:01.147023
# Optimization Progress:  93%|█████████▎| 94/101 [01:37<00:06,  1.05it/s, best_trial=5, best_value=0.631]INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.5870352	best: 0.5870352 (0)	total: 2.75ms	remaining: 13.8s
# INFO3:lightautoml.ml_algo.boost_cb:100:	test: 0.6228544	best: 0.6249124 (38)	total: 282ms	remaining: 13.7s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.6249123887
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 38
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 39 iterations.
# INFO:optuna.study.study:Trial 94 finished with value: 0.6249123887050583 and parameters: {'max_depth': 5, 'nan_mode': 'Min', 'l2_leaf_reg': 2.6977131986827063e-06, 'min_data_in_leaf': 9}. Best is trial 5 with value: 0.6308210816173305.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 95 with hyperparameters {'max_depth': 5, 'nan_mode': 'Min', 'l2_leaf_reg': 2.6977131986827063e-06, 'min_data_in_leaf': 9} scored 0.6249123887050583 in 0:00:00.473533
# Optimization Progress:  94%|█████████▍| 95/101 [01:37<00:04,  1.22it/s, best_trial=5, best_value=0.631]INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.5870352	best: 0.5870352 (0)	total: 2.55ms	remaining: 12.8s
# INFO3:lightautoml.ml_algo.boost_cb:100:	test: 0.6237182	best: 0.6240274 (41)	total: 276ms	remaining: 13.4s
# INFO3:lightautoml.ml_algo.boost_cb:200:	test: 0.6269658	best: 0.6272660 (197)	total: 570ms	remaining: 13.6s
# INFO3:lightautoml.ml_algo.boost_cb:300:	test: 0.6275856	best: 0.6285028 (250)	total: 842ms	remaining: 13.1s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.6285028053
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 250
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 251 iterations.
# INFO:optuna.study.study:Trial 95 finished with value: 0.6285031519268246 and parameters: {'max_depth': 5, 'nan_mode': 'Min', 'l2_leaf_reg': 3.8349528273488344e-05, 'min_data_in_leaf': 10}. Best is trial 5 with value: 0.6308210816173305.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 96 with hyperparameters {'max_depth': 5, 'nan_mode': 'Min', 'l2_leaf_reg': 3.8349528273488344e-05, 'min_data_in_leaf': 10} scored 0.6285031519268246 in 0:00:01.075099
# Optimization Progress:  95%|█████████▌| 96/101 [01:38<00:04,  1.11it/s, best_trial=5, best_value=0.631]INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.5870352	best: 0.5870352 (0)	total: 2.62ms	remaining: 13.1s
# INFO3:lightautoml.ml_algo.boost_cb:100:	test: 0.6248587	best: 0.6249602 (94)	total: 280ms	remaining: 13.6s
# INFO3:lightautoml.ml_algo.boost_cb:200:	test: 0.6263461	best: 0.6266712 (197)	total: 570ms	remaining: 13.6s
# INFO3:lightautoml.ml_algo.boost_cb:300:	test: 0.6251883	best: 0.6271641 (228)	total: 848ms	remaining: 13.2s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.6271641116
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 228
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 229 iterations.
# INFO:optuna.study.study:Trial 96 finished with value: 0.6271641116405341 and parameters: {'max_depth': 5, 'nan_mode': 'Min', 'l2_leaf_reg': 5.389214906337869e-06, 'min_data_in_leaf': 13}. Best is trial 5 with value: 0.6308210816173305.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 97 with hyperparameters {'max_depth': 5, 'nan_mode': 'Min', 'l2_leaf_reg': 5.389214906337869e-06, 'min_data_in_leaf': 13} scored 0.6271641116405341 in 0:00:01.031321
# Optimization Progress:  96%|█████████▌| 97/101 [01:39<00:03,  1.05it/s, best_trial=5, best_value=0.631]INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.5870352	best: 0.5870352 (0)	total: 2.61ms	remaining: 13.1s
# INFO3:lightautoml.ml_algo.boost_cb:100:	test: 0.6246888	best: 0.6252802 (98)	total: 411ms	remaining: 19.9s
# INFO3:lightautoml.ml_algo.boost_cb:200:	test: 0.6270366	best: 0.6272064 (185)	total: 1.13s	remaining: 27s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.6272064008
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 185
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 186 iterations.
# INFO:optuna.study.study:Trial 97 finished with value: 0.6272064007720193 and parameters: {'max_depth': 5, 'nan_mode': 'Min', 'l2_leaf_reg': 2.3416596952636517e-05, 'min_data_in_leaf': 19}. Best is trial 5 with value: 0.6308210816173305.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 98 with hyperparameters {'max_depth': 5, 'nan_mode': 'Min', 'l2_leaf_reg': 2.3416596952636517e-05, 'min_data_in_leaf': 19} scored 0.6272064007720193 in 0:00:01.817184
# Optimization Progress:  97%|█████████▋| 98/101 [01:41<00:03,  1.22s/it, best_trial=5, best_value=0.631]INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.5870352	best: 0.5870352 (0)	total: 3.56ms	remaining: 17.8s
# INFO3:lightautoml.ml_algo.boost_cb:100:	test: 0.6231335	best: 0.6233463 (96)	total: 764ms	remaining: 37.1s
# INFO3:lightautoml.ml_algo.boost_cb:200:	test: 0.6244632	best: 0.6245585 (137)	total: 1.46s	remaining: 34.9s
# INFO3:lightautoml.ml_algo.boost_cb:300:	test: 0.6268182	best: 0.6269367 (298)	total: 2.25s	remaining: 35.1s
# INFO3:lightautoml.ml_algo.boost_cb:400:	test: 0.6249852	best: 0.6271031 (315)	total: 2.64s	remaining: 30.3s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.6271031044
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 315
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 316 iterations.
# INFO:optuna.study.study:Trial 98 finished with value: 0.6271031043688832 and parameters: {'max_depth': 5, 'nan_mode': 'Min', 'l2_leaf_reg': 1.0435855433234764e-07, 'min_data_in_leaf': 12}. Best is trial 5 with value: 0.6308210816173305.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 99 with hyperparameters {'max_depth': 5, 'nan_mode': 'Min', 'l2_leaf_reg': 1.0435855433234764e-07, 'min_data_in_leaf': 12} scored 0.6271031043688832 in 0:00:02.831289
# Optimization Progress:  98%|█████████▊| 99/101 [01:44<00:03,  1.72s/it, best_trial=5, best_value=0.631]INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.5870352	best: 0.5870352 (0)	total: 3.74ms	remaining: 18.7s
# INFO3:lightautoml.ml_algo.boost_cb:100:	test: 0.6245398	best: 0.6323546 (19)	total: 252ms	remaining: 12.2s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.6323545826
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 19
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 20 iterations.
# INFO:optuna.study.study:Trial 99 finished with value: 0.632354582582008 and parameters: {'max_depth': 4, 'nan_mode': 'Min', 'l2_leaf_reg': 8.254820198435678e-06, 'min_data_in_leaf': 8}. Best is trial 99 with value: 0.632354582582008.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 100 with hyperparameters {'max_depth': 4, 'nan_mode': 'Min', 'l2_leaf_reg': 8.254820198435678e-06, 'min_data_in_leaf': 8} scored 0.632354582582008 in 0:00:00.400463
# Optimization Progress:  99%|█████████▉| 100/101 [01:45<00:01,  1.33s/it, best_trial=99, best_value=0.632]INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.6062476	best: 0.6062476 (0)	total: 3.32ms	remaining: 16.6s
# INFO3:lightautoml.ml_algo.boost_cb:100:	test: 0.6220014	best: 0.6248254 (13)	total: 255ms	remaining: 12.4s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.624825384
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 13
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 14 iterations.
# INFO:optuna.study.study:Trial 100 finished with value: 0.6248253840165108 and parameters: {'max_depth': 4, 'nan_mode': 'Max', 'l2_leaf_reg': 0.00018176574360563474, 'min_data_in_leaf': 8}. Best is trial 99 with value: 0.632354582582008.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 101 with hyperparameters {'max_depth': 4, 'nan_mode': 'Max', 'l2_leaf_reg': 0.00018176574360563474, 'min_data_in_leaf': 8} scored 0.6248253840165108 in 0:00:00.369833
# Optimization Progress: 100%|██████████| 101/101 [01:45<00:00,  1.04s/it, best_trial=99, best_value=0.632]
# [16:31:44] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost completed
# INFO:lightautoml.ml_algo.tuning.optuna:Hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost completed
# INFO2:lightautoml.ml_algo.tuning.optuna:The set of hyperparameters {'max_depth': 4, 'nan_mode': 'Min', 'l2_leaf_reg': 8.254820198435678e-06, 'min_data_in_leaf': 8}
#  achieve 0.6324 auc
# [16:31:44] Start fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ...
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'task_type': 'CPU', 'thread_count': 2, 'random_seed': 42, 'num_trees': 3000, 'learning_rate': 0.03, 'l2_leaf_reg': 8.254820198435678e-06, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 4, 'min_data_in_leaf': 8, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'boost_from_average': True, 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': 100, 'allow_writing_files': False, 'verbose_eval': 100}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.5870352	best: 0.5870352 (0)	total: 3.33ms	remaining: 9.98s
# INFO3:lightautoml.ml_algo.boost_cb:100:	test: 0.6213241	best: 0.6270632 (12)	total: 332ms	remaining: 9.52s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.6270632417
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 12
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 13 iterations.
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.6212325	best: 0.6212325 (0)	total: 6.64ms	remaining: 19.9s
# INFO3:lightautoml.ml_algo.boost_cb:100:	test: 0.6444157	best: 0.6458606 (52)	total: 248ms	remaining: 7.13s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.6458606467
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 52
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 53 iterations.
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.6007445	best: 0.6007445 (0)	total: 3.09ms	remaining: 9.27s
# INFO3:lightautoml.ml_algo.boost_cb:100:	test: 0.6393582	best: 0.6410677 (13)	total: 248ms	remaining: 7.13s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.6410677149
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 13
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 14 iterations.
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.5886011	best: 0.5886011 (0)	total: 6.08ms	remaining: 18.2s
# INFO3:lightautoml.ml_algo.boost_cb:100:	test: 0.6125099	best: 0.6182310 (6)	total: 277ms	remaining: 7.96s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.618230968
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 6
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 7 iterations.
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.5874655	best: 0.5874655 (0)	total: 4.26ms	remaining: 12.8s
# INFO3:lightautoml.ml_algo.boost_cb:100:	test: 0.6092587	best: 0.6108708 (73)	total: 249ms	remaining: 7.16s
# INFO3:lightautoml.ml_algo.boost_cb:200:	test: 0.6118030	best: 0.6118384 (199)	total: 487ms	remaining: 6.78s
# INFO3:lightautoml.ml_algo.boost_cb:300:	test: 0.6121117	best: 0.6124232 (264)	total: 723ms	remaining: 6.48s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.6124231931
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 264
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 265 iterations.
# [16:31:46] Fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost finished. score = 0.6033946842350502
# INFO:lightautoml.ml_algo.base:Fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost finished. score = 0.6033946842350502
# [16:31:46] Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost fitting and predicting completed
# [16:31:46] Time left 385.20 secs
# INFO:lightautoml.automl.base:Time left 385.20 secs
# [16:31:46] Layer 1 training completed.
# INFO:lightautoml.automl.base:Layer 1 training completed.
# [16:31:46] Blending: optimization starts with equal weights. Score = 0.6780130
# INFO:lightautoml.automl.blend:Blending: optimization starts with equal weights. Score = 0.6780130
# [16:31:46] Blending: iteration 0: score = 0.6855706, weights = [0.3503859  0.15537402 0.24492982 0.17225221 0.077058  ]
# INFO:lightautoml.automl.blend:Blending: iteration 0: score = 0.6855706, weights = [0.3503859  0.15537402 0.24492982 0.17225221 0.077058  ]
# [16:31:47] Blending: iteration 1: score = 0.6856607, weights = [0.37032697 0.15044034 0.24521966 0.16168319 0.07232989]
# INFO:lightautoml.automl.blend:Blending: iteration 1: score = 0.6856607, weights = [0.37032697 0.15044034 0.24521966 0.16168319 0.07232989]
# [16:31:47] Blending: no improvements for score. Terminated.
# INFO:lightautoml.automl.blend:Blending: no improvements for score. Terminated.
# [16:31:47] Blending: best score = 0.6856607, best weights = [0.37032697 0.15044034 0.24521966 0.16168319 0.07232989]
# INFO:lightautoml.automl.blend:Blending: best score = 0.6856607, best weights = [0.37032697 0.15044034 0.24521966 0.16168319 0.07232989]
# [16:31:47] Automl preset training completed in 215.45 seconds
# INFO:lightautoml.automl.presets.base:Automl preset training completed in 215.45 seconds
# [16:31:47] Model description:
# Final prediction for new objects (level 0) =
# 	 0.37033 * (5 averaged models Lvl_0_Pipe_0_Mod_0_LinearL2) +
# 	 0.15044 * (5 averaged models Lvl_0_Pipe_1_Mod_0_LightGBM) +
# 	 0.24522 * (5 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM) +
# 	 0.16168 * (5 averaged models Lvl_0_Pipe_1_Mod_2_CatBoost) +
# 	 0.07233 * (5 averaged models Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost)
# INFO:lightautoml.automl.presets.base:Model description:
# Final prediction for new objects (level 0) =
# 	 0.37033 * (5 averaged models Lvl_0_Pipe_0_Mod_0_LinearL2) +
# 	 0.15044 * (5 averaged models Lvl_0_Pipe_1_Mod_0_LightGBM) +
# 	 0.24522 * (5 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM) +
# 	 0.16168 * (5 averaged models Lvl_0_Pipe_1_Mod_2_CatBoost) +
# 	 0.07233 * (5 averaged models Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost)

# %%
from sklearn.metrics import roc_auc_score
import numpy as np

# %%
# 12) Предсказания на тестовом наборе
test_pred  = automl.predict(test_df)
test_proba = test_pred.data.ravel()
y_test     = test_df['target_column'].values

# %%
# 13) Функция для вычисления метрик
def calc_metrics(y_true, proba, thr=0.5):
    mask = ~np.isnan(proba)
    y, p = y_true[mask], proba[mask]
    preds = (p >= thr).astype(int)
    prec = precision_score(y, preds, zero_division=0)
    rec  = recall_score(y, preds, zero_division=0)
    f1   = f1_score(y, preds, zero_division=0)
    roc  = roc_auc_score(y, p)
    prc, rec_curve, _ = precision_recall_curve(y, p)
    pr_auc = auc(rec_curve, prc)
    return prec, rec, f1, roc, pr_auc

# %%
# 14) Подсчёт метрик и вывод
names    = ['Precision','Recall','F1-score','ROC-AUC','PR-AUC']
mt_train = calc_metrics(y_train_oof, train_proba)
mt_test  = calc_metrics(y_test,       test_proba)

print("=== Train metrics (OOF) ===")
for n,v in zip(names, mt_train):
    print(f"{n:10s}: {v:.4f}")
print("\n=== Test metrics ===")
for n,v in zip(names, mt_test):
    print(f"{n:10s}: {v:.4f}")
# Out:
# === Train metrics (OOF) ===
# Precision : 0.8054
# Recall    : 0.0839
# F1-score  : 0.1519
# ROC-AUC   : 0.6857
# PR-AUC    : 0.5412
#
# === Test metrics ===
# Precision : 0.7969
# Recall    : 0.0480
# F1-score  : 0.0906
# ROC-AUC   : 0.6912
# PR-AUC    : 0.5340
